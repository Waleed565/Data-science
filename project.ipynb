# %% [markdown]
# Portfolio \
# Written By: Hafiz waleed ahmad\
# Email: waleedrajpoot5657@gmail.com

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('api.trackcountry.csv')

# %%
df.head()
# Out:
#     country  total_cases  new_cases  total_deaths  new_deaths  \
# 0  Pakistan        35788          0           770           0
# 1  Pakistan        35788        490           770           9
# 2  Pakistan        35298          0           761           0
# 3  Pakistan        35298       2624           761          37
# 4  Pakistan        34336       1662           737          13
#
#    total_recovered  active_cases  serious_cases  tot_cases  \
# 0           9695.0         25323            111        162
# 1           9695.0         25323            111        162
# 2           8899.0         25638            111        160
# 3           8899.0         25638            111        160
# 4           8812.0         24787            111        155
#
#                          created_at
# 0  2020-05-15 02:02:41.000224+00:00
# 1  2020-05-14 04:00:33.601279+00:00
# 2  2020-05-14 01:01:47.983706+00:00
# 3  2020-05-13 21:01:41.911806+00:00
# 4  2020-05-13 03:01:26.250601+00:00

# %%
df.describe()
# Out:
#         total_cases    new_cases  total_deaths  new_deaths  total_recovered  \
# count    290.000000   290.000000    290.000000   290.00000       289.000000
# mean    7802.410345   271.427586    158.962069     5.97931      1746.986159
# std     8901.524962   417.658910    204.865156    10.09640      2465.106589
# min       19.000000     0.000000      0.000000     0.00000         0.000000
# 25%     1331.000000    19.250000      9.250000     0.00000        23.000000
# 50%     4035.000000   100.000000     57.000000     1.00000       429.000000
# 75%    11940.000000   284.000000    253.000000     7.00000      2755.000000
# max    35788.000000  2624.000000    770.000000    57.00000      9695.000000
#
#        active_cases  serious_cases   tot_cases
# count    290.000000     290.000000  290.000000
# mean    5902.486207      42.962069   35.275862
# std     6250.057925      43.423981   40.318023
# min       19.000000       0.000000    0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          290 non-null    object
#  1   total_cases      290 non-null    int64
#  2   new_cases        290 non-null    int64
#  3   total_deaths     290 non-null    int64
#  4   new_deaths       290 non-null    int64
#  5   total_recovered  289 non-null    float64
#  6   active_cases     290 non-null    int64
#  7   serious_cases    290 non-null    int64
#  8   tot_cases        290 non-null    int64
#  9   created_at       290 non-null    object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 22.8+ KB

# %%
df.shape
# Out:
# (290, 10)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# country            0.0
# total_cases        0.0
# new_cases          0.0
# total_deaths       0.0
# new_deaths         0.0
# total_recovered    0.0
# active_cases       0.0
# serious_cases      0.0
# tot_cases          0.0
# created_at         0.0
# dtype: float64

# %%
df.total_recovered.fillna(value=df['total_recovered'].mean(), inplace= True)
# Out:
# C:\Users\walee\AppData\Local\Temp\ipykernel_11056\3936169481.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.total_recovered.fillna(value=df['total_recovered'].mean(), inplace= True)

# %%
df.columns
# Out:
# Index(['country', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'total_recovered', 'active_cases', 'serious_cases', 'tot_cases',
#        'created_at'],
#       dtype='object')

# %%
sns.boxplot(data= df, x='total_deaths', y='total_cases')
# Out:
# <Axes: xlabel='total_deaths', ylabel='total_cases'>

# %%
sns.histplot(data=df, x='total_deaths')
# Out:
# <Axes: xlabel='total_deaths', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.select_dtypes(include=['number']))
# Out:
# <Axes: >

# %%
sns.countplot(data=df, x='total_cases')
# Out:
# <Axes: xlabel='total_cases', ylabel='count'>

# %%
sns.barplot(data=df, x='total_cases', y='created_at')
# Out:
# <Axes: xlabel='total_cases', ylabel='created_at'>

# %%
sns.histplot(data=df, x='total_cases', bins=30)
# Out:
# <Axes: xlabel='total_cases', ylabel='Count'>

# %%
sns.scatterplot(data=df, x='total_cases', y='total_deaths')
# Out:
# <Axes: xlabel='total_cases', ylabel='total_deaths'>

# %% [markdown]
# # Machine - Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
df.head()
# Out:
#     country  total_cases  new_cases  total_deaths  new_deaths  \
# 0  Pakistan        35788          0           770           0
# 1  Pakistan        35788        490           770           9
# 2  Pakistan        35298          0           761           0
# 3  Pakistan        35298       2624           761          37
# 4  Pakistan        34336       1662           737          13
#
#    total_recovered  active_cases  serious_cases  tot_cases  \
# 0           9695.0         25323            111        162
# 1           9695.0         25323            111        162
# 2           8899.0         25638            111        160
# 3           8899.0         25638            111        160
# 4           8812.0         24787            111        155
#
#                          created_at
# 0  2020-05-15 02:02:41.000224+00:00
# 1  2020-05-14 04:00:33.601279+00:00
# 2  2020-05-14 01:01:47.983706+00:00
# 3  2020-05-13 21:01:41.911806+00:00
# 4  2020-05-13 03:01:26.250601+00:00

# %%
df.columns
# Out:
# Index(['country', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'total_recovered', 'active_cases', 'serious_cases', 'tot_cases',
#        'created_at'],
#       dtype='object')

# %%
X= df[['total_cases','total_recovered', 'new_cases', 'active_cases', 'serious_cases', 'total_deaths']]
y = df['country']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
sns.scatterplot(x=y_test, y=y_pred)
# Out:
# <Axes: xlabel='total_deaths'>

# %%
sns.lmplot(data=df,x='total_deaths', y='total_cases')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mse = mean_squared_error(y_true= y_test, y_pred= y_pred)
rmse = mean_squared_error(y_true= y_test, y_pred= y_pred, squared=False)
mse =  mean_absolute_error(y_true= y_test, y_pred= y_pred)
r2 = r2_score(y_true= y_test, y_pred= y_pred)

print( 'mse:', mse )
print('mse:', mse)
print('rmse:', rmse)
print('r2:', r2)
# Out:
# mse: 8.661795896801724
# mse: 8.661795896801724
# rmse: 11.285923558968822
# r2: 0.9966370142238266
# c:\Users\walee\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          290 non-null    object
#  1   total_cases      290 non-null    int64
#  2   new_cases        290 non-null    int64
#  3   total_deaths     290 non-null    int64
#  4   new_deaths       290 non-null    int64
#  5   total_recovered  290 non-null    float64
#  6   active_cases     290 non-null    int64
#  7   serious_cases    290 non-null    int64
#  8   tot_cases        290 non-null    int64
#  9   created_at       290 non-null    object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 22.8+ KB

# %%
from sklearn.neighbors import KNeighborsRegressor
 
model = KNeighborsRegressor()
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mse = mean_squared_error(y_true= y_test, y_pred= y_pred)
rmse = mean_squared_error(y_true= y_test, y_pred= y_pred, squared=False)
mse =  mean_absolute_error(y_true= y_test, y_pred= y_pred)
r2 = r2_score(y_true= y_test, y_pred= y_pred)

print( 'mse:', mse )
print('mse:', mse)
print('rmse:', rmse)
print('r2:', r2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
X= df[['total_cases','total_recovered', 'new_cases', 'active_cases', 'serious_cases', 'total_deaths']]
y = df['country']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
model = KNeighborsClassifier()
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test)

# %%
print('f1_score:', f1_score(y_test, y_pred))
print('precision_score:', precision_score(y_test,y_pred))
print('recall_score:', recall_score(y_test, y_pred))
